# %%
import gymnasium as gym
env = gym.make("HalfCheetah-v5")

# %%
for i in [env.observation_space, env.action_space]:
    print(i)
# Out:
# Box(-inf, inf, (17,), float64)
# Box(-1.0, 1.0, (6,), float32)

# %%
import torch

x1 = torch.randn(3)
x2 = torch.randn(3)
print(x1, x2)
torch.min(
            x1, x2
        )
# Out:
# tensor([0.3272, 1.0461, 0.3290]) tensor([ 2.1571,  0.4686, -1.0670])
# tensor([ 0.3272,  0.4686, -1.0670])
